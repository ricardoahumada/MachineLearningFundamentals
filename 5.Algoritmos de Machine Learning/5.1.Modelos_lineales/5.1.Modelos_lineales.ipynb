# %% [markdown]
# # Modelos Lineales
#
# - para clasificación y regresión.
# - Modelos simples, fáciles de entender y rápidos de entrenar.

# %% [markdown]
# Un ejemplo: estimar los precios de la vivienda
#
# ![image-2.png](attachment:image-2.png)
#
# Aproximación lineal:
#
# ```
# Sale_Price = 0.1 * Gr_Liv_Area
# + 1.1 * Year_Built
# — I 8.9 * Fu11_Bath
# — 2200.0
# ```

# %% [markdown]
# ## Regresión lineal
# Predecir el valor del objetivo 'Y' dada alguna observación 'x'
#
# ```
# Sa1e_Price = 0.1 * Gr_Liv_Area
# - 2209.0
# ```
#
# ![image-4.png](attachment:image-4.png)
#
# **Ajustar una línea de predicción lo más cerca posible a todos los puntos de entrenamiento.**
#
# ![image-2.png](attachment:image-2.png)
#
# ### Con más variables:
#
# ```
# Sa1e_Price = 0.1 * Gr_Liv_Area
# + 1.1 * Year_Built
# - 2209.0
# ```
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## Clasificación: regresión logística
#
# - Para la clasificación, utilizamos un modelo de regresión logística: y es '0' o '1'
# - La salida del modelo se interpreta como la probabilidad de ser 1 para una x dada.
#
# ![image-3.png](attachment:image-3.png)
#
# ### Más dimensiones:
#
# ![image.png](attachment:image.png)
#
# ### Clasificación multiclase:
#
# - y en {0, 1,2}
#
# Para una entrada dada x:
# - Predecir una probabilidad por clase
# - las probabilidades suma a 1
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Los modelos lineales no son adecuados para todos los datos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusiones
# - líneas de base simples y rápidas para:
#     - regresión: regresión lineal
#     - Clasificación: regresión logística
# - Puede subajustar cuando: n_features << n_samples
#     - -> ¡La ingeniería de nuevas características puede ayudar!
# - Difícil de superar cuando N_Features es grande
