# %% [markdown]
# # Bagging y Random forests
#
# ## Bagging para clasifiación

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Se generan 3 variaciones de manera aleatoria
#
# ![image-3.png](attachment:image-3.png)
#
# - Un Árbol de decisión para cada variación (sin límite de depth)
#
# ![image-4.png](attachment:image-4.png)
#
# - Agrega las predicciones de todos los árboles para tomar una decisión
#
# ![image-2.png](attachment:image-2.png)
#
# - En skit learn:
# ```
#
# ```

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Bagging para regresión
#
# ![image.png](attachment:image.png)
#
#
# - Selecciona múltiples subconjuntos aleatorios de los datos
#
# ![image-3.png](attachment:image-3.png)
#
# - Ajusta un modelo a cada uno
#
# ![image-4.png](attachment:image-4.png)
#
#
# - Predice el promedio
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Bagging versus Random forest
#
# - El bagging es una estrategia general
#     - Puede ajustar cualquier modelo base (lineal, árboles ...)
#
# - Los Random forests son árboles de decisión **aleatorios** en bolsas (bags)
#     - En cada división: se seleccionan un subconjunto *aleatorio* de características
#     - Se toma *la mejor división*  entre el subconjunto restringido
#     - La extra-aleatorización decorrela los errores de predicción > hace que el paso de promedio del algoritmo funcione mejor.

# %% [markdown]
# ## Conclusiones
#
# Bagging y Random forests ajustan los árboles de forma independiente
# - Cada árbol [profundo] se sobreajusta individualmente
# - promediar las predicciones del árbol reduce el sobreajuste
